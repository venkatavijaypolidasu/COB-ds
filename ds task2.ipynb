# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTSS-TcErkXNk8KB0AlijhitwetxeHD2M3R0HJl2QPMAyFq0fxFX4PFKnzAWLDnratIz67DNL6GsZnV/pub?output=csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
c=df.columns
for i in c:
    df[i]=df[i].replace('not given',pd.NA)
    print(i,'Done')
# Out:
# show_id Done
# type Done
# title Done
# director Done
# country Done
# date_added Done
# release_year Done
# rating Done
# duration Done
# listed_in Done

# %%
df['date_added']=pd.to_datetime(df['date_added'], errors='coerce')
df['date_added']=df['date_added'].dt.strftime('%d/%m/%y')

# %%
mis_val=df.isnull().sum()
mis_val
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title('missing values')
# Out:
# Text(0.5, 1.0, 'missing values')

# %%
df=df.drop('director',axis=1)
df
# Out:
#      show_id     type                             title        country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#      date_added  release_year rating   duration  \
# 0      25/09/21          2020  PG-13     90 min
# ...

# %%
df['country']=df.country.fillna(df['country'].mode()[0])

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
def fun(duration):
    try:
        return int("".join(fillter(str.isdigit, duration)))
    except:
        return None

# %%
df['duration']=df['duration'].apply(fun)

# %%
Q1=df['duration'].quantile(0.25)
Q3=df['duration'].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

# %%
outliers=df[(df['duration']<lower)|(df['duration']>upper)]
len(outliers)
# Out:
# 0

# %%
df_cleaned_duration=df[~((df['duration']<lower)|(df['duration']>upper))]

# %%
Q1_year=df['release_year'].quantile(0.25)
Q3_year=df['release_year'].quantile(0.75)
IQR_year=Q3_year-Q1_year
lower_year=Q1_year-1.5*IQR_year
upper_year=Q3_year+1.5*IQR_year

# %%
outliers_year=df[(df['release_year']<lower_year)|(df['release_year']>upper_year)]
outliers_year
# Out:
#      show_id     type                                title        country  \
# 4         s8    Movie                              Sankofa  United States
# 29       s25    Movie                                Jeans          India
# 51       s27    Movie                       Minsara Kanavu          India
# 53       s23    Movie                      Avvai Shanmughi      Not Given
# 60       s42    Movie                                 Jaws  United States
# ...      ...      ...                                  ...            ...
# 8702   s8232    Movie                             The Bund      Hong Kong
# 8743   s8524  TV Show    The Super Mario Bros. Super Show!  United States
# 8746   s8542  TV Show  The Twilight Zone (Original Series)  United States
# 8761   s8645  TV Show                           Twin Peaks  United States
# 8765   s8670  TV Show                        V.R. Troopers  United States
#
#      date_added  release_year rating duration  \
# ...

# %%
df_cleaned=df_cleaned_duration[~((df_cleaned_duration['release_year']<lower_year)|(df_cleaned_duration['release_year']>upper_year))]

# %%
df_cleaned.reset_index(drop=True,inplace=True)

# %%
df_cleaned
# Out:
#      show_id     type                             title         country  \
# 0         s1    Movie              Dick Johnson Is Dead   United States
# 1         s3  TV Show                         Ganglands          France
# 2         s6  TV Show                     Midnight Mass   United States
# 3        s14    Movie  Confessions of an Invisible Girl          Brazil
# 4         s9  TV Show     The Great British Baking Show  United Kingdom
# ...      ...      ...                               ...             ...
# 8068   s8797  TV Show                        Yunus Emre          Turkey
# 8069   s8798  TV Show                         Zak Storm   United States
# 8070   s8801  TV Show                Zindagi Gulzar Hai        Pakistan
# 8071   s8784  TV Show                              Yoko        Pakistan
# 8072   s8786  TV Show                               YOM        Pakistan
#
#      date_added  release_year rating duration  \
# 0      25/09/21          2020  PG-13     None
# ...

# %%
df.to_csv('cleaned_dataset.csv',index=False)
